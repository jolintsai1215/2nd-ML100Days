# %% [markdown]
# ## 作業1
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# I chose "Personalized Medicine: Redefining Cancer Treatment" from Kaggle competition. This research field is what I want to get involved in the future. It is important because personalized medicine by machine learning can change the traditional way of the cancer treatment.
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# The data is collected from clinical evidence provided by Memorial Sloan Kettering Cancer Center (MSKCC). The researchers and oncologists have annotated the tumor mutations manually.
#
# 3. 蒐集而來的資料型態為何
#
# There are four data files provided, training_variants, training_text, test_variants, and test_text. The variants files are csv file containing fields of ID, Gene, Variation, and Class. The The text files are also csv file but containing only ID and text (clinical evidence).
#
# 4. 這組資料想解決的問題如何評估
#
# This competition is trying to develop algorithm to classify 9 classes of genetic mutation from unstructured clinical data, which is text. We may use multiclass classification for this problem.

# %% [markdown]
# ## 作業2
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# Increase the number of customers having similar routes and decrease the fare to make more people willing to join the car-pool service during peak time.
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#
# - the routes of people during peak time
# - the number of people getting on and off in different districts
# - the fare of the rides
# - the time people spending on waiting
#
#
# 3. 蒐集而來的資料型態為何
#
#
# - longitude and latitude : text
# - number of costumers : number
# - fare : number
# - time : number
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#
# - check if more people joining the pool service if they have similar routes
# - check if the income increases or not

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - y_hat) ** 2) / len(y)
    return mse

# %%
def mean_absolute_error(y, y_hat):
    mae = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 275.914
# The Mean absolute error is 12.771
